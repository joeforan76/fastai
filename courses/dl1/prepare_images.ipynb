# %%
import os
import sys
import random
from google_images_download import google_images_download
from PIL import Image

# %%
def download_data(cat_info, out_dir, args):
    for ci in cat_info:
        args["keywords"] = ci['keyword']
        args["output_directory"] = f"{out_dir}/{ci['name']}"
        gid = google_images_download.googleimagesdownload()
        gid.download(args)

# %%
def mkdir_if_needed(path):
    if not os.path.exists(path):
        print(f"Creating directory {path}")
        os.mkdir(path)
    elif not os.path.isdir(path):
        print(f'{path} already exists and is not a directory')
        raise FileExistsError
        
def mkdir_and_parents(path):
    print("Path: {}".format(path))
    ancestors=path.split('/')
    for i in range(len(ancestors)):
        subpath = ('/' if path[0] == '/' else '') + '/'.join(ancestors[:(i+1)])
        print(f"Subpath: {subpath}")
        mkdir_if_needed(subpath)
        
    
def prepare_category_directories(new_dir, categories):
    for cat in categories:
        mkdir_and_parents(f'{new_dir}/{cat.name}')

# %%
def check_download_data(category_info, download_root):
    valid_images = {}
    
    def is_valid_image(fp):
        try:
            im = Image.open(fp)
            im.load()
        except Exception as e:
            print(f"Error loading {fp}: {e}")
            return False
        return True
        
    for ci in category_info:
        valid_images[ci['name']] = []
        walk_res = os.walk("{}/{}".format(download_root, ci['name']))
        for wr in walk_res:
            for fn in wr[2]:
                fp = os.path.join(wr[0], fn)
                if is_valid_image(fp):
                    valid_images[ci['name']].append(fp)

    return valid_images

# %%
def choose_mode(modes, mode_split):
    st = sum(mode_split)
    rv = random.random() * st
    ct = 0
    for m,s in zip(modes, mode_split):
        if rv < (ct + s):
            return m
        ct += s

# %%
def copy_image(src_path, dst_path):
    try:
        im = Image.open(src_path)
        im.save(dst_path)
    except Exception as e:
        print(f"Error trying to save image. Src: {src_path}. Error: {str(e)}")

# %%
def copy_images(valid_images, problem_dir):
    data_modes = ['train', 'eval', 'test']
    data_split = [0.8, 0.1, 0.1]

    for dm in data_modes:
        mkdir_and_parents(f'{problem_dir}/{dm}')
    
    test_images = []

    for key in valid_images:
        non_test_modes = [dm for dm in data_modes if 'test' not in dm]
        cur_counts = {}
        for dm in non_test_modes:
            cur_counts[dm] = 0
            mkdir_and_parents(f'{problem_dir}/{dm}/{key}')
        for f in valid_images[key]:
            mode = choose_mode(data_modes, data_split)
            if mode == 'test':
                test_images.append((key, f))
            else:
                cur_counts[mode] += 1
                dest = f"{problem_dir}/{mode}/{key}/{cur_counts[mode]:0{4}}.jpg"
                print(f"Copying {f} to {dest}")
                copy_image(f, dest)

    random.shuffle(test_images)

    test_count = 0
    with open(f"{problem_dir}/test/test_ground_truth.txt", 'w') as of:
        for i,ti in enumerate(test_images):
            test_num = i + 1
            dest = f"{problem_dir}/test/{test_num:0{4}}.jpg"
            print(f"Copying {ti[1]} to {dest}")
            copy_image(ti[1], dest)
            of.write("{}\t{}\n".format(dest, ti[0]))

# %%
def prepare(download_root, category_info, problem_dir, args):
    
    mkdir_and_parents(f'{download_root}')
    download_data(category_info, download_root, args)
    valid_images = check_download_data(category_info, download_root)
    copy_images(valid_images, problem_dir)

# %%
# !rm -rf data/cities/
# !rm -rf data/test_downloads

# %%
category_info = [{
'keyword': 'Tokyo',
'name': 'tokyo'},
{
'keyword': 'New York',
'name': 'newyork'}]

args = {
    "limit" : 100,
    "type": "photo",
    "size": "medium",
    "format": "jpg"
}

ROOT_DIR='./data'
download_root = f'{ROOT_DIR}/test_downloads'
problem_name = 'cities'
problem_dir = f"{ROOT_DIR}/{problem_name}"
prepare(download_root, category_info, problem_dir, args)
# Out:
# Path: ./data/test_downloads
# Subpath: .
# Subpath: ./data
# Subpath: ./data/test_downloads
# Creating directory ./data/test_downloads
#
# Item no.: 1 --> Item name = Tokyo
# Evaluating...
# Starting Download...
# Completed Image ====> 1. n-tokyo-a-20180715-870x580.jpg
# Completed Image ====> 2. https%3a%2f%2fs3-ap-northeast-1.amazonaws.com%2fpsh-ex-ftnikkei-3937bb4%2fimages%2f5%2f9%2f3%2f7%2f13677395-2-eng-gb%2fthumbnail_image-1.jpg
# Completed Image ====> 3. n-tokyo-a-20171013-870x581.jpg
# Completed Image ====> 4. hero_tokyo.jpg
# Completed Image ====> 5. tokyo-main.jpg
# Completed Image ====> 6. lek_office_photos_2017_0004_tokyo_0.jpg
# Completed Image ====> 7. tokyo_best_student_cities.jpg
# Completed Image ====> 8. 0441edc7-tokyo-banner--.jpg
# Completed Image ====> 9. tokyo-earthquake-tokyo-earthquake-japan-tokyo-earthquake-latest-tokyo-earthquake-magnitude-tokyo-earthquake-usgs-tokyo-939132.jpg
# Completed Image ====> 10. tokyo_780x520px.ash
# Completed Image ====> 11. rcyhr61w_tokyo2.jpg
# Completed Image ====> 12. 15397778192_f6bc0e5261_b.jpg
# Completed Image ====> 13. 20170203013703_1059021555_13245_0.jpg
# Completed Image ====> 14. tokyo-destination-06?$mo_masthead-property-mobile$.jpg
# Completed Image ====> 15. tokyo-japan-shutterstock-810x445.jpg
# Completed Image ====> 16. 350px-tokyo_montage_2015.jpg
# Completed Image ====> 17. xxwsws1idjzgmkdlafsj.jpg
# Completed Image ====> 18. shutterstock_248980975.jpg
# Completed Image ====> 19. gallery-1493894118-tokyo-guida-ai-quartieri.jpg
# Completed Image ====> 20. tokyo-left.jpg
# Completed Image ====> 21. 1500px-tokyo_from_the_top_of_the_skytree_%28cropped%29.jpg
# IOError on an image...trying next one... Error: The read operation timed out
# Completed Image ====> 22. tokyo_tower_01.jpg
# Completed Image ====> 23. tokyo-2193354_960_720.jpg
# Completed Image ====> 24. tokyo-skyline.jpg
# Completed Image ====> 25. winter-lights-roppongi-tokyo-b4f60a4cc18b.jpg
# URLError on an image...trying next one... Error: <urlopen error [Errno -2] Name or service not known>
# Completed Image ====> 26. ?w=620&h=413&crop=1&hash=42b7953656d0313e83bb600dd148dfb430c5d9fc.jpg
# Completed Image ====> 27. tokyo-wine-bars-and-restaurants-630x417.jpg
# Completed Image ====> 28. 05c1324a000003e8-0-image-a-2_1512472055057.jpg
# Completed Image ====> 29. spotifylocations465x465_tokyo-1.jpg
# Completed Image ====> 30. top_01.jpg
# Completed Image ====> 31. tokyo-giappone.jpg
# Completed Image ====> 32. tokyo.jpg
# Completed Image ====> 33. zebra-crossing-in-shinjuku-tokyo-at-sunset-picture-id545087716?s=612x612.jpg
# Completed Image ====> 34. tokyo-skyline-night1.jpg
# Completed Image ====> 35. ogp_ja.jpg
# Completed Image ====> 36. skytree_40011_01.jpg
jpg
#
#
# Unfortunately all 100 could not be downloaded because some images were not downloadable. 98 is all we got for this search filter!
#
# Errors: 2
#
#
# Item no.: 1 --> Item name = New York
# Evaluating...
# Starting Download...
# Completed Image ====> 1. new-york-2017-columbus-circle-01?$mo_masthead-property-mobile$.jpg
# Completed Image ====> 2. freedom-tower.jpg
# Completed Image ====> 3. thumb_148242_cover_header.jpeg
# Completed Image ====> 4. newyork.jpg
# Completed Image ====> 5. image.jpg
# Completed Image ====> 6. 27007567.jpg
# Completed Image ====> 7. new-york-city-statue-of-liberty-hotels.ng_.jpg
# Completed Image ====> 8. pexels-photo-450597.jpeg
# Completed Image ====> 9. us-ny-new_york.jpg
# Completed Image ====> 10. exterior.jpg
# Completed Image ====> 11. new-york-city-2380683_960_720.jpg
# Completed Image ====> 12. new-york.jpg
# Completed Image ====> 13. image.jpg
# Completed Image ====> 14. 000c61da-800.jpg
# Completed Image ====> 15. .jpg
# Completed Image ====> 16. thinkstockphotos-615398376.jpg
# Completed Image ====> 17. new-york-city-skyline-central-park-autumn-foliage-aerial-view-picture-id494607942?s=612x612.jpg
# Completed Image ====> 18. 5aa2ad7db2f7b825008b46f8-750-562.jpg
# Completed Image ====> 19. new-york-manhattan-hero-1309px.jpg
# Completed Image ====> 20. 920x920.jpg
# Completed Image ====> 21. new-york-2017-columbus-circle-day?wid=720&hei=1080&fmt=jpeg&qlt=75,0&op_sharpen=0&resmode=sharp2&op_usm=0.8,0.8,5,0&iccembed=0&printres=72&fit=crop.jpg
# Completed Image ====> 22. aebc04da-3591-4ea4-bfe8-f5ea726a4447.hw1.jpg
# Completed Image ====> 23. 7%e6%9c%88%e3%81%ae%e3%83%8b%e3%83%a5%e3%83%bc%e3%83%a8%e3%83%bc%e3%82%af.jpg
# Completed Image ====> 24. nyc_skyline_module_image.jpg
# Completed Image ====> 25. new-york-top-image.jpg
# Completed Image ====> 26. cayetano-gil-518367-unsplash-homepage-choose-campus_670x720_0.jpg
# Completed Image ====> 27. nueva-york-m.jpg
# Completed Image ====> 28. 8120_1.jpg
# Completed Image ====> 29. zero-newyork_mv.jpg
# Completed Image ====> 30. 534311071_642x856.jpg
# Completed Image ====> 31. ilsu_dest_nyc_stage_desktop.jpg
# Completed Image ====> 32. new-york-aerial.jpg
# Completed Image ====> 33. new-york-exclusive.jpg
# Completed Image ====> 34. gettyimages-126889040.jpg
# Completed Image ====> 35. 650px-new_york_midtown_skyline_at_night_-_jan_2006_edit1.jpg
# Completed Image ====> 36. newyork.jpg
# Completed Image ====> 37. img_main.jpg
# Completed Image ====> 38. nybrooklynbridge.jpg
# Completed Image ====> 39. 51s-yl80%2bwl.jpg
# Completed Image ====> 40. new-york-2048866_960_720.jpg
# Completed Image ====> 41. 08e99cb5_z.jpg
# Completed Image ====> 42. times-square-new-york.jpg
# Completed Image ====> 43. ficha_nyc.jpg
# Completed Image ====> 93. newyorkcity-web1024x768-02-36d4b322.jpg
# Completed Image ====> 94. ny2_3169807a-large.jpg
# Completed Image ====> 95. time-square-new-york-city-picture-id487537456?b=1&k=6&m=487537456&s=612x612&w=0&h=zumik3gqgmj3ynctej4-tm0dem22xo0onhhxk_ff03u=.jpg
# Completed Image ====> 96. p4rseyibt4gzh3eqq66k.jpg
# Completed Image ====> 97. new_york.jpg
# Completed Image ====> 98. new-york-riverdale-hero-1309px.jpg
# Completed Image ====> 99. ?url=http%3a%2f%2fmedia.beam.usnews.com%2f67%2f03%2f781c1012412086bae07910f920fe%2fresizes%2f1500%2fbs17-new-york-editorial.jpg.jpg
# Completed Image ====> 100. 43725742.jpg
#
# Errors: 0
#
# Error loading ./data/test_downloads/tokyo/Tokyo/39. shibuya-tokyo.jpg: cannot identify image file './data/test_downloads/tokyo/Tokyo/39. shibuya-tokyo.jpg'
# Error loading ./data/test_downloads/tokyo/Tokyo/70. tokyo-shopping-lead-akihabara.jpg: cannot identify image file './data/test_downloads/tokyo/Tokyo/70. tokyo-shopping-lead-akihabara.jpg'
# Error loading ./data/test_downloads/tokyo/Tokyo/13. 20170203013703_1059021555_13245_0.jpg: cannot identify image file './data/test_downloads/tokyo/Tokyo/13. 20170203013703_1059021555_13245_0.jpg'
# Error loading ./data/test_downloads/newyork/New York/72. ?media_id=1454424374815958.jpg: cannot identify image file './data/test_downloads/newyork/New York/72. ?media_id=1454424374815958.jpg'
# Error loading ./data/test_downloads/newyork/New York/79. 4527de3f_z.jpg: cannot identify image file './data/test_downloads/newyork/New York/79. 4527de3f_z.jpg'
# Error loading ./data/test_downloads/newyork/New York/37. img_main.jpg: cannot identify image file './data/test_downloads/newyork/New York/37. img_main.jpg'
# Error loading ./data/test_downloads/newyork/New York/25. new-york-top-image.jpg: cannot identify image file './data/test_downloads/newyork/New York/25. new-york-top-image.jpg'
# Path: ./data/cities/train
# Subpath: .
# Subpath: ./data
# Subpath: ./data/cities
# Creating directory ./data/cities
# Subpath: ./data/cities/train
# Creating directory ./data/cities/train
# Path: ./data/cities/eval
# Subpath: .
# Subpath: ./data
# Subpath: ./data/cities
# Subpath: ./data/cities/eval
# Creating directory ./data/cities/eval
# Path: ./data/cities/test
# Subpath: .
# Subpath: ./data
# Subpath: ./data/cities
# Subpath: ./data/cities/test
# Creating directory ./data/cities/test
# Path: ./data/cities/train/tokyo
# Subpath: .
# Subpath: ./data
# Subpath: ./data/cities
# Subpath: ./data/cities/train
# Subpath: ./data/cities/train/tokyo
# Creating directory ./data/cities/train/tokyo
# Path: ./data/cities/eval/tokyo
# Subpath: .
# Subpath: ./data
# Subpath: ./data/cities
# Subpath: ./data/cities/eval
# Subpath: ./data/cities/eval/tokyo
# Creating directory ./data/cities/eval/tokyo
# Copying ./data/test_downloads/tokyo/Tokyo/61. 917200183.jpg to ./data/cities/eval/tokyo/0001.jpg
# Copying ./data/test_downloads/tokyo/Tokyo/76. top-10-things-to-do-and-see-in-tokyo.jpg to ./data/cities/train/tokyo/0001.jpg
# Copying ./data/test_downloads/tokyo/Tokyo/67. tokyo_japan_9_0.jpg to ./data/cities/train/tokyo/0002.jpg
# Copying ./data/test_downloads/tokyo/Tokyo/12. 15397778192_f6bc0e5261_b.jpg to ./data/cities/train/tokyo/0003.jpg
# Copying ./data/test_downloads/tokyo/Tokyo/20. tokyo-left.jpg to ./data/cities/train/tokyo/0004.jpg
# Copying ./data/test_downloads/tokyo/Tokyo/85. tyo_640.jpg to ./data/cities/train/tokyo/0005.jpg
# Copying ./data/test_downloads/tokyo/Tokyo/84. bw-tokyo_2020.jpg to ./data/cities/train/tokyo/0006.jpg
# Copying ./data/test_downloads/tokyo/Tokyo/21. 1500px-tokyo_from_the_top_of_the_skytree_%28cropped%29.jpg to ./data/cities/train/tokyo/0007.jpg
# Copying ./data/test_downloads/tokyo/Tokyo/79. cq5dam.rendition.900.450.jpg to ./data/cities/train/tokyo/0008.jpg
# Copying ./data/test_downloads/tokyo/Tokyo
jpg
# Copying ./data/test_downloads/tokyo/Tokyo/53. pic2_180209.jpg to ./data/cities/eval/tokyo/0010.jpg
# Path: ./data/cities/train/newyork
# Subpath: .
# Subpath: ./data
# Subpath: ./data/cities
# Subpath: ./data/cities/train
# Subpath: ./data/cities/train/newyork
# Creating directory ./data/cities/train/newyork
# Path: ./data/cities/eval/newyork
# Subpath: .
# Subpath: ./data
# Subpath: ./data/cities
# Subpath: ./data/cities/eval
# Subpath: ./data/cities/eval/newyork
# Creating directory ./data/cities/eval/newyork
# Copying ./data/test_downloads/newyork/New York/78. marquee-sm-new-york.jpg to ./data/cities/eval/newyork/0001.jpg
# Copying ./data/test_downloads/newyork/New York/23. 7%e6%9c%88%e3%81%ae%e3%83%8b%e3%83%a5%e3%83%bc%e3%83%a8%e3%83%bc%e3%82%af.jpg to ./data/cities/train/newyork/0001.jpg
# Copying ./data/test_downloads/newyork/New York/96. p4rseyibt4gzh3eqq66k.jpg to ./data/cities/train/newyork/0002.jpg
# Copying ./data/test_downloads/newyork/New York/24. nyc_skyline_module_image.jpg to ./data/cities/train/newyork/0003.jpg
# Copying ./data/test_downloads/newyork/New York/10. exterior.jpg to ./data/cities/train/newyork/0004.jpg
# Copying ./data/test_downloads/newyork/New York/38. nybrooklynbridge.jpg to ./data/cities/train/newyork/0005.jpg
# Copying ./data/test_downloads/newyork/New York/3. thumb_148242_cover_header.jpeg to ./data/cities/train/newyork/0006.jpg
# Copying ./data/test_downloads/newyork/New York/95. time-square-new-york-city-picture-id487537456?b=1&k=6&m=487537456&s=612x612&w=0&h=zumik3gqgmj3ynctej4-tm0dem22xo0onhhxk_ff03u=.jpg to ./data/cities/train/newyork/0007.jpg
# Copying ./data/test_downloads/newyork/New York/29. zero-newyork_mv.jpg to ./data/cities/train/newyork/0008.jpg
# Copying ./data/test_downloads/newyork/New York/93. newyorkcity-web1024x768-02-36d4b322.jpg to ./data/cities/train/newyork/0009.jpg
# Copying ./data/test_downloads/newyork/New York/62. prices_01.jpg to ./data/cities/eval/newyork/0002.jpg
# Copying ./data/test_downloads/newyork/New York/36. newyork.jpg to ./data/cities/train/newyork/0010.jpg
# Copying ./data/test_downloads/newyork/New York/32. new-york-aerial.jpg to ./data/cities/eval/newyork/0003.jpg
# Copying ./data/test_downloads/newyork/New York/84. img_roppongi.jpg to ./data/cities/train/newyork/0011.jpg
# Copying ./data/test_downloads/newyork/New York/47. ph1.jpg to ./data/cities/train/newyork/0012.jpg
# Copying ./data/test_downloads/newyork/New York/74. img_main.jpg to ./data/cities/train/newyork/0013.jpg
# Copying ./data/test_downloads/newyork/New York/57. cityscapes-new-york-manhattan-skyline-night-01?$bgv-hero-main$.jpg to ./data/cities/train/newyork/0014.jpg
# Copying ./data/test_downloads/newyork/New York/46. 22998-1-ny-in-a-day.jpg to ./data/cities/train/newyork/0015.jpg
# Copying ./data/test_downloads/newyork/New York/9. us-ny-new_york.jpg to ./data/cities/train/newyork/0016.jpg
# Copying ./data/test_downloads/newyork/New York/69. newyork2016.jpg to ./data/cities/train/newyork/0017.jpg
# Copying ./data/test_downloads/newyork/New York/40. new-york-2048866_960_720.jpg to ./data/cities/train/newyork/0018.jpg
# Copying ./data/test_downloads/newyork/New York/58. shop_elknyb_a_4.jpg to ./data/cities/train/newyork/0019.jpg
# Copying ./data/test_downloads/newyork/New York/45. new-york-ase.jpg to ./data/cities/train/newyork/0046.jpg
# Copying ./data/test_downloads/newyork/New York/15. .jpg to ./data/cities/train/newyork/0047.jpg
# Copying ./data/test_downloads/newyork/New York/20. 920x920.jpg to ./data/cities/train/newyork/0048.jpg
# Copying ./data/test_downloads/newyork/New York/14. 000c61da-800.jpg to ./data/cities/train/newyork/0049.jpg
# Copying ./data/test_downloads/newyork/New York/92. 5f2c09b0dcbb244ef6ee7709885ce618e67ddb48.47.1.26.2.jpg to ./data/cities/train/newyork/0050.jpg
# Copying ./data/test_downloads/newyork/New York/77. 5a38ae93-37f8-4106-b4de-18400aba16f5.png to ./data/cities/train/newyork/0051.jpg
# Copying ./data/test_downloads/newyork/New York/55. nycmq-exterior-0166-hor-feat.jpg to ./data/cities/eval/newyork/0004.jpg
# Copying ./data/test_downloads/newyork/New York/28. 8120_1.jpg to ./data/cities/train/newyork/0052.jpg
# Copying ./data/test_downloads/newyork/New York/89. the-city-of-dreams-new-york-citys-skyline-at-twilight-picture-id599766748?s=612x612.jpg to ./data/cities/train/newyork/0053.jpg
# Copying ./data/test_downloads/newyork/New York/87. 20171005_nyt_catalunya_top-w960.jpg to ./data/cities/train/newyork/0054.jpg
# Copying ./data/test_downloads/newyork/New York/82. new-york-1157991.jpg to ./data/cities/train/newyork/0055.jpg
# Copying ./data/test_downloads/newyork/New York/97. new_york.jpg to ./data/cities/train/newyork/0056.jpg
# Copying ./data/test_downloads/newyork/New York/63. new-york-water-taxi-hop-on-hop-off-all-day-pass-1.jpg to ./data/cities/train/newyork/0057.jpg
# Copying ./data/test_downloads/newyork/New York/18. 5aa2ad7db2f7b825008b46f8-750-562.jpg to ./data/cities/train/newyork/0058.jpg
# Copying ./data/test_downloads/newyork/New York/76. 8aa0208d_z.jpg to ./data/cities/train/newyork/0059.jpg
# Copying ./data/test_downloads/newyork/New York/91. new-york-basic-info.jpg to ./data/cities/eval/newyork/0005.jpg
# Copying ./data/test_downloads/newyork/New York/1. new-york-2017-columbus-circle-01?$mo_masthead-property-mobile$.jpg to ./data/cities/train/newyork/0060.jpg
# Copying ./data/test_downloads/newyork/New York/75. image.jpg to ./data/cities/train/newyork/0061.jpg
# Copying ./data/test_downloads/newyork/New York/19. new-york-manhattan-hero-1309px.jpg to ./data/cities/train/newyork/0062.jpg
# Copying ./data/test_downloads/newyork/New York/39. 51s-yl80%2bwl.jpg to ./data/cities/train/newyork/0063.jpg
# Copying ./data/test_downloads/newyork/New York/44. view-of-new-york-brooklyn-bridge-night-slider-big-bus-tours-jan-2017.jpg to ./data/cities/train/newyork/0064.jpg
# Copying ./data/test_downloads/newyork/New York/70. big-apple-pass1.jpg to ./data/cities/train/newyork/0065.jpg
# Copying ./data/test_downloads/newyork/New York/98. new-york-riverdale-hero-1309px.jpg to ./data/cities/train/newyork/0066.jpg
# Copying ./data/test_downloads/newyork/New York/35. 650px-new_york_midtown_skyline_at_night_-_jan_2006_edit1.jpg to ./data/cities/train/newyork/0067.jpg
# Copying ./data/test_downloads/newyork/New York/7. new-york-city-statue-of-liberty-hotels.ng_.jpg to ./data/cities/train/newyork/0068.jpg
# Copying ./data/test_downloads/newyork/New York/4. newyork.jpg to ./data/cities/train/newyork/0069.jpg
# Copying ./data/test_downloads/newyork/New York/73. the-ritz-carlton-new-york-central-park.jpg to ./data/cities/train/newyork/0070.jpg
# Copying ./data/test_downloads/newyork/New York/8. pexels-photo-450597.jpeg to ./data/cities/train/newyork/0071.jpg
# Copying ./data/test_downloads/newyork/New York/54. new_york_destination-images_673x263.jpg to ./data/cities/train/newyork/0072.jpg
# Copying ./data/test_downloads/newyork/New York/6. 27007567.jpg to ./data/cities/train/newyork/0073.jpg
# Copying ./data/test_downloads/newyork/New York/21. new-york-2017-columbus-circle-day?wid=720&hei=1080&fmt=jpeg&qlt=75,0&op_sharpen=0&resmode=sharp2&op_usm=0.8,0.8,5,0&iccembed=0&printres=72&fit=crop.jpg to ./data/cities/train/newyork/0074.jpg
# Copying ./data/test_downloads/newyork/New York/31. ilsu_dest_nyc_stage_desktop.jpg to ./data/cities/train/newyork/0075.jpg
# Copying ./data/test_downloads/newyork/New York/13. image.jpg to ./data/cities/train/newyork/0076.jpg
# Copying ./data/test_downloads/newyork/New York/53. directly-from-ny.jpg to ./data/cities/train/newyork/0077.jpg
# Copying ./data/test_downloads/newyork/New York/94. ny2_3169807a-large.jpg to ./data/cities/eval/newyork/0006.jpg
# Copying ./data/test_downloads/newyork/New York/2. freedom-tower.jpg to ./data/cities/train/newyork/0078.jpg
# Copying ./data/test_downloads/tokyo/Tokyo/29. spotifylocations465x465_tokyo-1.jpg to ./data/cities/test/0001.jpg
# Copying ./data/test_downloads/tokyo/Tokyo/30. top_01.jpg to ./data/cities/test/0002.jpg
# Copying ./data/test_downloads/newyork/New York/52. 2500px-skyline-new-york-city.jpg to ./data/cities/test/0003.jpg
# Copying ./data/test_downloads/newyork/New York/59. 51o8puxq8nl.jpg to ./data/cities/test/0004.jpg
# Copying ./data/test_downloads/newyork/New York/90. img_main.jpg to ./data/cities/test/0005.jpg
# Copying ./data/test_downloads/tokyo/Tokyo/28. 05c1324a000003e8-0-image-a-2_1512472055057.jpg to ./data/cities/test/0006.jpg
# Copying ./data/test_downloads/newyork/New York/26. cayetano-gil-518367-unsplash-homepage-choose-campus_670x720_0.jpg to ./data/cities/test/0007.jpg
# Copying ./data/test_downloads/newyork/New York/33. new-york-exclusive.jpg to ./data/cities/test/0008.jpg
# Copying ./data/test_downloads/tokyo/Tokyo/65. tokyo.jpg to ./data/cities/test/0009.jpg
# Copying ./data/test_downloads/tokyo/Tokyo/59. d2d853d7f041bb52e101c457bf7d7d2319b9655a.jpg to ./data/cities/test/0010.jpg
# Copying ./data/test_downloads/newyork/New York/80. hamilton-park.jpg to ./data/cities/test/0011.jpg
# Copying ./data/test_downloads/tokyo/Tokyo/17. xxwsws1idjzgmkdlafsj.jpg to ./data/cities/test/0012.jpg
# Copying ./data/test_downloads/newyork/New York/85. ec_new_york_img05.jpg to ./data/cities/test/0013.jpg
# Copying ./data/test_downloads/tokyo/Tokyo/88. 201808-ginzasonypark_l_full.jpg to ./data/cities/test/0014.jpg
# Copying ./data/test_downloads/tokyo/Tokyo/98. main_img.jpg to ./data/cities/test/0015.jpg
# Copying ./data/test_downloads/newyork/New York/43. ficha_nyc.jpg to ./data/cities/test/0016.jpg
# Copying ./data/test_downloads/newyork/New York/68. 110317272.jpg to ./data/cities/test/0017.jpg
# Copying ./data/test_downloads/newyork/New York/88. directly-from-ny-image.jpg to ./data/cities/test/0018.jpg
# Copying ./data/test_downloads/newyork/New York/71. nycmain.jpg to ./data/cities/test/0019.jpg
